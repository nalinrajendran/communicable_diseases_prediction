# %% [markdown]
# # Exploratory Data Analysis of our data

# %% [raw]
# Exploratory data analysis is the crucial process of doing first investigations on data in order to find patterns, uncover anomalies, test hypotheses, and double-check assumptions using summaries of statistics and graphical representations.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import seaborn as sns
# %matplotlib inline

# %%
#Reading The datafile containing the dengue case count along with along other weather features
pwd = os.getcwd()
filepath = os.path.join(pwd,r"DATA/try_data.csv")
filepath
# Out:
# '/Users/nalinrajendran/Desktop/STUDY/MIS  SIP PAPER/OUR CODE/COMMENTED/DATA/try_data.csv'

# %%
raw_data = pd.read_csv(filepath)
raw_data
# Out:
#       state  year  month  cases  mean_temp  relative_hum   prec  prec_sum  \
# 0    Kerala  2011      1     68      23.47         72.81   0.04      0.00
# 1    Kerala  2011      2     41      24.90         65.56   1.58     47.46
# 2    Kerala  2011      3     54      27.33         61.00   0.44     10.55
# 3    Kerala  2011      4     53      27.20         72.94   4.01    105.47
# 4    Kerala  2011      5     84      26.72         79.38   4.33    121.29
# ..      ...   ...    ...    ...        ...           ...    ...       ...
# 127  Kerala  2021      8    327      24.03         90.50   8.42    261.11
# 128  Kerala  2021      9    194      24.33         90.50   7.28    218.52
# 129  Kerala  2021     10    215      24.67         90.38  13.33    413.24
# 130  Kerala  2021     11    192      24.08         90.06  10.07    302.14
# 131  Kerala  2021     12    261      23.30         83.44   1.05     32.42
#
#      humi_spe  temp_max  temp_min  temp_avg  dew_point
# ...

# %%
raw_data.head()
# Out:
#     state  year  month  cases  mean_temp  relative_hum  prec  prec_sum  \
# 0  Kerala  2011      1     68      23.47         72.81  0.04      0.00
# 1  Kerala  2011      2     41      24.90         65.56  1.58     47.46
# 2  Kerala  2011      3     54      27.33         61.00  0.44     10.55
# 3  Kerala  2011      4     53      27.20         72.94  4.01    105.47
# 4  Kerala  2011      5     84      26.72         79.38  4.33    121.29
#
#    humi_spe  temp_max  temp_min  temp_avg  dew_point
# 0     13.18     32.30     16.42    24.360      17.61
# 1     12.63     33.97     16.10    25.035      16.65
# 2     13.37     36.56     18.12    27.340      17.42
# 3     16.42     36.91     22.50    29.705      21.04
# 4     17.70     34.47     22.46    28.465      22.43

# %%
raw_data.tail()
# Out:
#       state  year  month  cases  mean_temp  relative_hum   prec  prec_sum  \
# 127  Kerala  2021      8    327      24.03         90.50   8.42    261.11
# 128  Kerala  2021      9    194      24.33         90.50   7.28    218.52
# 129  Kerala  2021     10    215      24.67         90.38  13.33    413.24
# 130  Kerala  2021     11    192      24.08         90.06  10.07    302.14
# 131  Kerala  2021     12    261      23.30         83.44   1.05     32.42
#
#      humi_spe  temp_max  temp_min  temp_avg  dew_point
# 127     17.52     28.51     20.41    24.460      22.26
# 128     17.82     29.17     21.54    25.355      22.57
# 129     18.19     28.85     22.11    25.480      22.90
# 130     17.52     28.38     20.90    24.640      22.27
# 131     15.38     28.65     16.59    22.620      20.12

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   state         132 non-null    object
#  1   year          132 non-null    int64
#  2   month         132 non-null    int64
#  3   cases         132 non-null    int64
#  4   mean_temp     132 non-null    float64
#  5   relative_hum  132 non-null    float64
#  6   prec          132 non-null    float64
#  7   prec_sum      132 non-null    float64
#  8   humi_spe      132 non-null    float64
#  9   temp_max      132 non-null    float64
#  10  temp_min      132 non-null    float64
#  11  temp_avg      132 non-null    float64
#  12  dew_point     132 non-null    float64
# dtypes: float64(9), int64(3), object(1)
# memory usage: 13.5+ KB

# %% [markdown]
# describe() is very handy in getting various summary statistics.
# This function returns the count, mean, standard deviation, minimum and maximum values and the quantiles of the data.

# %%
raw_data.describe()
# Out:
#               year       month        cases   mean_temp  relative_hum  \
# count   132.000000  132.000000   132.000000  132.000000    132.000000
# mean   2016.000000    6.500000   483.984848   25.412121     78.569167
# std       3.174324    3.465203   785.498033    1.631589     12.025662
# min    2011.000000    1.000000    41.000000   23.300000     52.000000
# 25%    2013.000000    3.750000   129.750000   24.205000     66.892500
# 50%    2016.000000    6.500000   258.000000   24.700000     82.625000
# 75%    2019.000000    9.250000   481.750000   26.505000     89.297500
# max    2021.000000   12.000000  5555.000000   29.550000     92.500000
#
#              prec    prec_sum    humi_spe    temp_max    temp_min    temp_avg  \
# count  132.000000  132.000000  132.000000  132.000000  132.000000  132.000000
# mean     5.213333  154.496136   16.093864   32.165909   20.096591   26.131250
# std      4.915950  151.150037    2.167127    3.613296    2.139324    2.158619
# ...

# %% [markdown]
# # Correlation Check between the target variable and other attributes

# %% [markdown]
# Correlation matrix - Simply said, a correlation matrix is a table that shows the correlation coefficients for various variables.
# The correlation between all potential pairs of values in a table is shown in the matrix.
# It is an effective tool for compiling a sizable dataset and for locating and displaying data patterns.

# %%
plt.figure(figsize = (15,9))
corelation = raw_data.corr()
corelation
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns, annot=True)
# Out:
# <AxesSubplot:>

# %%
index = 0
monthYears = []
years= [i for i in raw_data.year]
for i in raw_data.month:
    monthYears.append(str(years[index])+'-'+str(i))
    index += 1
plt.figure(figsize=(14,6))
sns.lineplot(x=monthYears,y=[i for i in raw_data['cases']],color='black')
plt.title(label='Dengue fever cases from 2011-2021')
plt.xlabel(xlabel='Month')
plt.ylabel(ylabel='Cases')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize = (14,6))
raw_data.groupby('year')['cases'].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# # The above bar graph indicates the yearwise count of dengue cases from 2011 to 2021

# %%
plt.figure(figsize = (14,10))

raw_data.corr().abs().cases.drop('cases').sort_values().plot.barh(color='darkblue')
plt.title('Variables Correlation with cases variables')
# Out:
# Text(0.5, 1.0, 'Variables Correlation with cases variables')

# %% [markdown]
# # The above graph indicates the correlation between the case count and other parameters

# %%
plt.figure(figsize=(17,8))
(raw_data
     .cases
     .plot
     .line(lw=0.8))
plt.title('Dengue cases in Kerala ', fontsize = 25)
plt.xlabel('Time',fontsize = 20)
# Out:
# Text(0.5, 0, 'Time')

# %% [markdown]
# # The above graph indicates the variation of the cases over time(time-series variation)

# %%
plt.figure(figsize=(17,8))
(raw_data
     .prec
     .plot
     .line(lw=0.8))

plt.title('Rainfall impact over Time')
plt.xlabel('Time')
# Out:
# Text(0.5, 0, 'Time')

# %%
sns.pairplot(raw_data)
#the plot relates the relationship between the variables of our data

# %%
plt.figure(figsize=(17,8))
raw_data.plot(x="cases", y="prec", kind="scatter")
# Out:
# <AxesSubplot:xlabel='cases', ylabel='prec'>

# %%
def compCase (year):
    year = int(year)
    year_20xx = raw_data.loc[raw_data['year'] == year]
    
    fig,a =  plt.subplots(2, figsize=(13,5), gridspec_kw={'height_ratios': [1, 2]})
    a[0].plot(year_20xx["prec"])
    a[0].set_title('RAINFALL')
    a[1].plot(year_20xx["cases"])
    a[1].set_title('CASES')
    fig.suptitle('Year '+ str(year), fontsize=20)
    plt.show()

# %% [markdown]
# # The below graphs indicate that there is high correlation between the rainfall pattern and the case count , as indicated in the graphs below.

# %% [markdown]
# # These inference play a vital role in our analysis, when highly influence for the spike of cases

# %% [markdown]
# # The first graph indicates the rainfall pattern .The second graph indicates the cases count variation over time

# %%
compCase(2011)

# %%
compCase(2012)

# %%
compCase(2013)

# %%
compCase(2014)

# %%
compCase(2015)

# %%
compCase(2016)

# %%
compCase(2017)

# %%
compCase(2018)

# %%
compCase(2019)

# %%
compCase(2020)

# %%
compCase(2021)
